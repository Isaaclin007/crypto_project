# %%
import eth_test

# %%
import mean_reversion

# %%
eth_test.main()
# Out:
# ('Start Time:', datetime.datetime(2018, 10, 1, 0, 0))
# ('End Time:', datetime.datetime(2019, 1, 2, 0, 0))
# (             Trace Statistic  Criti_90%  Criti_95%  Criti_99%
# NULL: r <=
# 0                  33.893120    13.4294    15.4943    19.9349
# 1                   1.687536     2.7055     3.8415     6.6349, '\n')
# (             Eigen Statistic  Criti_90%  Criti_95%  Criti_99%
# NULL: r <=
# 0                  32.205584    12.2971    14.2639    18.5200
# 1                   1.687536     2.7055     3.8415     6.6349, '\n')
# (   Eigen Value
# 0     0.000245
# 1     0.000013, '\n')
#           0         1
# 0  0.602664  0.007008
# 1 -0.601547  0.013340
# ('ADF static', -6.719081525241068)
# ('pValue', 3.5204558599915005e-09)
# ('Critical Value', {'5%': -2.8615619783754456, '1%': -3.4303997264626256, '10%': -2.566781698310064})

# %%
eth_test.main.df_last()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-aa51789e6678> in <module>()
# ----> 1 eth_test.main.df_last()
#
# AttributeError: 'function' object has no attribute 'df_last'

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-00cf07b74dcd> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined
